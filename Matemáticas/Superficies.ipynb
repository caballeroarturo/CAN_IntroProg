# %% [markdown]
# <a href="https://colab.research.google.com/github/caballeroarturo/CAN_IntroProg/blob/main/Matem%C3%A1ticas/Superficies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Superficies en 3D

# %% [markdown]
# ### 1. Plano

# %% [markdown]
# $$
# z = 2x + y + 1
# $$

# %% [markdown]
# ## 2. Esfera

# %%
import plotly.graph_objects as go

# %% [markdown]
# $$
# x^2 + y^2 + z^2 = 9
# $$

# %%
import numpy as np
import plotly.graph_objects as go

u=np.linspace(0,2*np.pi,50)
v=np.linspace(0,np.pi,50)

x=5*np.outer(np.cos(u),np.sin(v))
y=5*np.outer(np.sin(u),np.sin(v))
z=5*np.outer(np.ones(len(u)),np.cos(v))

fig=go.Figure(go.Surface(x=x,y=y,z=z))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 2. Cilindro circular

# %% [markdown]
# $$
# x^2 + y^2 = 4
# $$

# %% [markdown]
# ## 4. Cono circular

# %% [markdown]
# $$
# z = \sqrt{x^2 + y^2}
# $$
#
# También puede escribirse como
#
# $$
# z^2 = x^2 + y^2
# $$

# %% [markdown]
# ## 5. Paraboloide elíptico
#
# $$
# z = x^2 + y^2
# $$

# %% [markdown]
# ## 6. Paraboloide hiperbólico (silla de montar)

# %% [markdown]
# $$
# z = x^2 - y^2
# $$

# %% [markdown]
# ## 7. Elipsoide

# %% [markdown]
# $$
# \frac{x^2}{9} +
# \frac{y^2}{4} +
# \frac{z^2}{16}
# = 1
# $$

# %% [markdown]
# ## 8. Hiperboloide de una hoja

# %% [markdown]
# $$
# x^2 + y^2 - z^2 = 1
# $$

# %% [markdown]
# ## 9. Hiperboloide de dos hojas

# %% [markdown]
# $$
# z^2 - x^2 - y^2 = 1
# $$
